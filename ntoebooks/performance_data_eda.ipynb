# %%
import pandas as pd

# %%
perfom_data = pd.read_csv("../data/Archive-last/Challenge_Data/performance_data.csv")

# %%
perfom_data.head(30)
# Out:
#                                               game_id  \
# 0                    bfbf7a2b7ac635e67877b1ab87fd6629
# 1                    945010afbf9a55bbdffcb0895f946155
# 2                    e68e20f592457b875ce29757ab855dfe
# 3                   adunit-nestle-purina-friskies-mob
# 4   adunit-lionsgate-uwomt-user-slider-sensory-vid...
# 5                    84327cf26d2a91e2730ae7ddbfca6d59
# 6                    08b7a12a72fb5100b27197c39bab1b70
# 7               adunit-lionsgate-spiral-puzzle-v2-mpu
# 8                    bb631902fce625cf0dc87d80c027c905
# 9   adunit-western-union-sensory-unit-swipe-right-...
# 10                   bcc5ae4665b6b8c2ff25dfdc65fbc65a
# 11                       adunit-chevy-hotspot-cpe-mpu
# 12            adunit-yamaha-user-slider-rotate-v3-mob
# 13                   adunit-showtime-dexture-post-mpu
# 14                   7fc571f85358c5d37efafde99b6896d7
# 15            adunit-jaguar-nameplate-refresh-rfb-mpu
# ...

# %%
perfom_data.describe()
# Out:
#                ER         CTR
# count  905.000000  905.000000
# mean     0.136318    0.034466
# std      0.091524    0.036967
# min      0.000000    0.000000
# 25%      0.070338    0.007926
# 50%      0.118624    0.024537
# 75%      0.190722    0.047796
# max      0.524498    0.297410
